# %% [markdown]
# # Project: Drawing insights from Stack Overflow 2024 Annual Developer Survey
#
# ## Introduction:
# I will be using Stack Overflow's Annual Developer Survey data to draw business insights and train a predictive model to assist stakeholder's data driven decision making.
#
# Data is downloaded from: https://survey.stackoverflow.co/

# %% [markdown]
# #### Dataset Description:
# There are seven sections in this survey. The 2nd, 3rd, 4th, and 5th sections will
# appear in a random order.
# 1. Basic Information
# 2. Education, Work, and Career
# 3. Technology and Tech Culture
# 4. Stack Overflow Usage + Community
# 5. Artificial Intelligence
# 6. Professional Developer Series (Optional)
# 7. Final Questions
# Most questions in this survey are optional. Required questions are marked with *.
# This anonymous survey will take about 15 minutes to complete. We encourage you
# to complete it in one sitting.
#
# **I am only interested in section 1 and 2 so I will be creating a subset later on**

# %% [markdown]
# ## Business Understanding:
#
# > What size organizations do most developers work at who completed the survey.
#
# > How does Organization Size Affect Income?
#
# > Create a machine learning model to predict income based on 'Age', 'EdLevel', 'OrgSize', 'CompTotal' and 'YearsCodePro' in the US.

# %% [markdown]
# ## Data Understanding:
#
# > Explore data sources and data quality.
#
# > Conduct initial exploratory data analysis (EDA) using visualization and statistics.

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('survey_results_public2024.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  \
# 0                                                NaN
# 1  Technical documentation;Blogs;Books;Written Tu...
# 2  Technical documentation;Blogs;Books;Written Tu...
# 3  Stack Overflow;How-to videos;Interactive tutorial
# 4  Technical documentation;Blogs;Written Tutorial...
#
#                                              TechDoc YearsCode YearsCodePro  \
# 0                                                NaN       NaN          NaN
# 1  API document(s) and/or SDK document(s);User gu...        20           17
# 2  API document(s) and/or SDK document(s);User gu...        37           27
# 3                                                NaN         4          NaN
# 4  API document(s) and/or SDK document(s);User gu...         9          NaN
#
#                  DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy  \
# 0                    NaN     NaN               NaN        NaN        NaN
# 1  Developer, full-stack     NaN               NaN        NaN        NaN
# 2   Developer Experience     NaN               NaN        NaN        NaN
# 3  Developer, full-stack     NaN               NaN        NaN        NaN
# 4  Developer, full-stack     NaN               NaN        NaN        NaN
#
#   TechEndorse                                            Country Currency  \
# 0         NaN                           United States of America      NaN
# 1         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 2         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 3         NaN                                             Canada      NaN
# 4         NaN                                             Norway      NaN
#
#    CompTotal                             LanguageHaveWorkedWith  \
# 0        NaN                                                NaN
# 1        NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2        NaN                                                 C#
# 3        NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4        NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                               LanguageWantToWorkWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#                                      LanguageAdmired  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#             DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                              NaN                         NaN
# 1      Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2       Firebase Realtime Database  Firebase Realtime Database
# 3  MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 4                PostgreSQL;SQLite           PostgreSQL;SQLite
#
#               DatabaseAdmired                    PlatformHaveWorkedWith  \
# 0                         NaN                                       NaN
# 1                  PostgreSQL  Amazon Web Services (AWS);Heroku;Netlify
# 2  Firebase Realtime Database                              Google Cloud
# 3    MongoDB;MySQL;PostgreSQL   Amazon Web Services (AWS);Fly.io;Heroku
# 4           PostgreSQL;SQLite                                       NaN
#
#                      PlatformWantToWorkWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3          Amazon Web Services (AWS);Vercel
# 4                                       NaN
#
#                             PlatformAdmired  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3                 Amazon Web Services (AWS)
# 4                                       NaN
#
#                    WebframeHaveWorkedWith            WebframeWantToWorkWith  \
# 0                                     NaN                               NaN
# 1           Express;Next.js;Node.js;React  Express;Htmx;Node.js;React;Remix
# 2                            ASP.NET CORE                      ASP.NET CORE
# 3  jQuery;Next.js;Node.js;React;WordPress      jQuery;Next.js;Node.js;React
# 4                                     NaN                               NaN
#
#                 WebframeAdmired   EmbeddedHaveWorkedWith  \
# 0                           NaN                      NaN
# 1         Express;Node.js;React                      NaN
# 2                  ASP.NET CORE              Rasberry Pi
# 3  jQuery;Next.js;Node.js;React              Rasberry Pi
# 4                           NaN  CMake;Cargo;Rasberry Pi
#
#   EmbeddedWantToWorkWith    EmbeddedAdmired  \
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2            Rasberry Pi        Rasberry Pi
# 3                    NaN                NaN
# 4      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                             MiscTechHaveWorkedWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                     NumPy;Pandas;Ruff;TensorFlow
# 4                                              NaN
#
#                             MiscTechWantToWorkWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                                    MiscTechAdmired  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                               Docker;npm;Pip
# 4                                 APT;Make;npm
#
#                        ToolsTechWantToWorkWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                        Docker;Kubernetes;npm
# 4                                     APT;Make
#
#                               ToolsTechAdmired  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                                   Docker;npm
# 4                                     APT;Make
#
#           NEWCollabToolsHaveWorkedWith         NEWCollabToolsWantToWorkWith  \
# 0                                  NaN                                  NaN
# 1  PyCharm;Visual Studio Code;WebStorm  PyCharm;Visual Studio Code;WebStorm
# 2                        Visual Studio                        Visual Studio
# 3                                  NaN                                  NaN
# 4                                  Vim                                  Vim
#
#                  NEWCollabToolsAdmired        OpSysPersonal use  \
# 0                                  NaN                      NaN
# 1  PyCharm;Visual Studio Code;WebStorm            MacOS;Windows
# 2                        Visual Studio                  Windows
# 3                                  NaN                      NaN
# 4                                  Vim  Other (please specify):
#
#   OpSysProfessional use                     OfficeStackAsyncHaveWorkedWith  \
# 0                   NaN                                                NaN
# 1                 MacOS                                                NaN
# 2               Windows                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN  GitHub Discussions;Markdown File;Obsidian;Stac...
#
#               OfficeStackAsyncWantToWorkWith  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                      OfficeStackAsyncAdmired  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 0                                           NaN                           NaN
# 1                         Microsoft Teams;Slack                         Slack
# 2  Google Chat;Google Meet;Microsoft Teams;Zoom  Google Chat;Google Meet;Zoom
# 3                                           NaN                           NaN
# 4                              Discord;Whatsapp              Discord;Whatsapp
#
#          OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# 0                           NaN                       NaN
# 1                         Slack                       NaN
# 2  Google Chat;Google Meet;Zoom                       NaN
# 3                           NaN                       NaN
# 4              Discord;Whatsapp                       NaN
#
#   AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
#
#                                           NEWSOSites             SOVisitFreq  \
# 0  I have never visited Stack Overflow or the Sta...                     NaN
# 1  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
# 2  Stack Overflow;Stack Exchange;Stack Overflow B...  Multiple times per day
# 3                                     Stack Overflow   Daily or almost daily
# 4  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
#
#   SOAccount              SOPartFreq  \
# 0       NaN                     NaN
# 1       Yes  Multiple times per day
# 2       Yes  Multiple times per day
# 3        No                     NaN
# 4       Yes  Multiple times per day
#
#                                                SOHow           SOComm  \
# 0                                                NaN              NaN
# 1  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 3                     Quickly finding code solutions   No, not really
# 4  Quickly finding code solutions;Engage with com...  Yes, definitely
#
#                   AISelect          AISent  \
# 0                      Yes  Very favorable
# 1  No, and I don't plan to             NaN
# 2  No, and I don't plan to             NaN
# 3                      Yes  Very favorable
# 4  No, and I don't plan to             NaN
#
#                                                AIBen           AIAcc  \
# 0                              Increase productivity             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Increase productivity;Greater efficiency;Impro...  Somewhat trust
# 4                                                NaN             NaN
#
#                        AIComplex  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  Bad at handling complex tasks
# 4                            NaN
#
#                                AIToolCurrently Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Learning about a codebase;Project planning;Wri...
# 4                                                NaN
#
#                            AIToolInterested in Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Testing code;Committing and reviewing code;Pre...
# 4                                                NaN
#
#   AIToolNot interested in Using  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                           AINextMuch more integrated AINextNo change  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Learning about a codebase;Project planning;Wri...             NaN
# 4                                                NaN             NaN
#
#   AINextMore integrated AINextLess integrated AINextMuch less integrated  \
# 0                   NaN                   NaN                        NaN
# 1                   NaN                   NaN                        NaN
# 2                   NaN                   NaN                        NaN
# 3                   NaN                   NaN                        NaN
# 4                   NaN                   NaN                        NaN
#
#   AIThreat                                           AIEthics  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                                NaN
# 3       No  Circulating misinformation or disinformation;M...
# 4      NaN                                                NaN
#
#                         AIChallenges TBranch                  ICorPM  WorkExp  \
# 0                                NaN      No                     NaN      NaN
# 1                                NaN     Yes  Individual contributor     17.0
# 2                                NaN      No                     NaN      NaN
# 3  Don’t trust the output or answers     NaN                     NaN      NaN
# 4                                NaN     NaN                     NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5  \
# 0         NaN         NaN         NaN         NaN         NaN
# 1       Agree    Disagree       Agree       Agree       Agree
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
#                   Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9 Frequency_1  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1  Neither agree nor disagree    Disagree       Agree       Agree         NaN
# 2                         NaN         NaN         NaN         NaN         NaN
# 3                         NaN         NaN         NaN         NaN         NaN
# 4                         NaN         NaN         NaN         NaN         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering Frustration  \
# 0         NaN         NaN           NaN           NaN         NaN
# 1         NaN         NaN           NaN           NaN         NaN
# 2         NaN         NaN           NaN           NaN         NaN
# 3         NaN         NaN           NaN           NaN         NaN
# 4         NaN         NaN           NaN           NaN         NaN
#
#   ProfessionalTech ProfessionalCloud ProfessionalQuestion Industry  \
# 0              NaN               NaN                  NaN      NaN
# 1              NaN               NaN                  NaN      NaN
# 2              NaN               NaN                  NaN      NaN
# 3              NaN               NaN                  NaN      NaN
# 4              NaN               NaN                  NaN      NaN
#
#    JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# 0             NaN             NaN             NaN             NaN
# 1             0.0             0.0             0.0             0.0
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# 0             NaN             NaN             NaN              NaN
# 1             0.0             0.0             0.0              0.0
# 2             NaN             NaN             NaN              NaN
# 3             NaN             NaN             NaN              NaN
# 4             NaN             NaN             NaN              NaN
#
#    JobSatPoints_11           SurveyLength SurveyEase  ConvertedCompYearly  \
# 0              NaN                    NaN        NaN                  NaN
# 1              0.0                    NaN        NaN                  NaN
# 2              NaN  Appropriate in length       Easy                  NaN
# 3              NaN               Too long       Easy                  NaN
# 4              NaN              Too short       Easy                  NaN
#
#    JobSat
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#Let's create a subset of the features we are interested in
df_sub = df[['Age', 'EdLevel', 'OrgSize', 'Country', 'CompTotal', 'YearsCodePro']]

# %% [markdown]
# ## Data Preparation
#
# > Merge, clean, and transform data.
#
# > Address issues like outliers and missing values.

# %%
df_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           65437 non-null  object
#  1   EdLevel       60784 non-null  object
#  2   OrgSize       47480 non-null  object
#  3   Country       58930 non-null  object
#  4   CompTotal     33740 non-null  float64
#  5   YearsCodePro  51610 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 3.0+ MB

# %%
# Let's drop all null values so that we can work with a clean precise dataframe
df_sub = df_sub.dropna()

# %%
# Confirming we dropped all the null values
df_sub.isna().sum()
# Out:
# Age             0
# EdLevel         0
# OrgSize         0
# Country         0
# CompTotal       0
# YearsCodePro    0
# dtype: int64

# %%
# Let's look at CompTotal first and clean this field up
df_sub['CompTotal'].describe()
# Out:
# count    3.359200e+04
# mean     2.976899e+60
# std      5.456097e+62
# min      0.000000e+00
# 25%      6.000000e+04
# 50%      1.100000e+05
# 75%      2.500000e+05
# max      1.000000e+65
# Name: CompTotal, dtype: float64

# %%
# Let's get a better look at the distribution with a boxplot
sns.boxplot(data=df_sub, x='CompTotal');

# %% [markdown]
# It seems like there are some clear outliers in our dataset. Perhaps its because not all currency is in USD. Let's filter it out to make sure all of our data is within the US.

# %%
# Let's filter out all countries except for the United States so that CompTotal can be consistent
# since currency scaling is different in different countries.

df_sub = df_sub[df_sub['Country'].str.contains('United States')]
df_sub.head()
# Out:
#                  Age                                            EdLevel  \
# 389  25-34 years old  Some college/university study without earning ...
# 398  45-54 years old  Some college/university study without earning ...
# 428  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 431  35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 432  35-44 years old  Secondary school (e.g. American high school, G...
#
#                       OrgSize                   Country  CompTotal  \
# 389        10 to 19 employees  United States of America   110000.0
# 398  1,000 to 4,999 employees  United States of America   195000.0
# 428      100 to 499 employees  United States of America   230000.0
# 431        20 to 99 employees  United States of America    85000.0
# 432        10 to 19 employees  United States of America   160000.0
#
#     YearsCodePro
# 389            7
# 398           30
# 428           11
# 431           23
# 432           18

# %%
df_sub['CompTotal'].describe()
# Out:
# count    7.013000e+03
# mean     1.595456e+11
# std      1.326832e+13
# min      0.000000e+00
# 25%      1.040000e+05
# 50%      1.475000e+05
# 75%      2.000000e+05
# max      1.111111e+15
# Name: CompTotal, dtype: float64

# %%
# Definitely looks better, but it still seems like there are outliers. Let's figure what it is and remove it.
# Let's remove anyone who makes more than $500,000 annually
df_sub[df_sub['CompTotal'] > 500000]
# Out:
#                    Age                                            EdLevel  \
# 529    25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 828    35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1488   25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1932   25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2171   35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                ...                                                ...
# 61590  45-54 years old  Some college/university study without earning ...
# 61736  35-44 years old  Secondary school (e.g. American high school, G...
# 62894  35-44 years old  Some college/university study without earning ...
# 62906  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63588  25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                         OrgSize                   Country  CompTotal  \
# 529    10,000 or more employees  United States of America   650000.0
# 828    10,000 or more employees  United States of America  1000000.0
# 1488   10,000 or more employees  United States of America   600000.0
# 1932   1,000 to 4,999 employees  United States of America   945000.0
# 2171       100 to 499 employees  United States of America   750000.0
# ...                         ...                       ...        ...
# 61590  1,000 to 4,999 employees  United States of America   750000.0
# 61736          2 to 9 employees  United States of America   780000.0
# 62894        20 to 99 employees  United States of America   600000.0
# 62906  10,000 or more employees  United States of America   550000.0
# 63588  10,000 or more employees  United States of America   620000.0
#
#       YearsCodePro
# 529             10
# 828             15
# 1488             8
# 1932             3
# 2171            17
# ...            ...
# 61590           25
# 61736            5
# 62894           15
# 62906            8
# 63588           14
#
# [106 rows x 6 columns]

# %%
# Filtering the dataframe of people who make more than $500k annually
df_cleaned = df_sub[df_sub['CompTotal'] < 500000]

# %%
df_cleaned['CompTotal'].describe()
# Out:
# count      6881.000000
# mean     154286.860485
# std       75341.456165
# min           0.000000
# 25%      102000.000000
# 50%      145000.000000
# 75%      191797.000000
# max      498000.000000
# Name: CompTotal, dtype: float64

# %%
plt.figure(figsize = [10,5])
sns.boxplot(data=df_cleaned, x='CompTotal')
# Out:
# <Axes: xlabel='CompTotal'>

# %% [markdown]
# This looks a lot better! Now let's move on and clean up our YearsCodePro field!

# %%
df_cleaned['YearsCodePro'].unique()
# Out:
# array(['7', '30', '11', '23', '18', '10', '26', '40', '4', '9', '22', '1',
#        '3', '20', '25', '13', '19', '15', '35', '31', '24', '17', '5',
#        '2', '12', '28', '6', '38', 'Less than 1 year', '8', '14', '27',
#        '21', 'More than 50 years', '34', '16', '29', '32', '43', '33',
#        '45', '36', '37', '44', '42', '41', '39', '46', '48', '50', '47',
#        '49'], dtype=object)

# %% [markdown]
# Not all of the responses within YearCodePro are numerical. We will need to fix that in order to create a machine learning model later down the line!
#
# Let's get that fixed right now!

# %%
# Function to clean 'YearsCodePro'
def clean_experience(x):
    if x == 'More than 50 years':
        return 51
    if x == 'Less than 1 year':
        return 0.5
    return float(x)

# Apply the function
df_cleaned['YearsCodePro'] = df_cleaned['YearsCodePro'].apply(clean_experience)

# Verify the change
print(df_cleaned['YearsCodePro'].dtype)
df_cleaned['YearsCodePro'].unique()
# Out:
# float64
# /tmp/ipython-input-2905464186.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['YearsCodePro'] = df_cleaned['YearsCodePro'].apply(clean_experience)
# array([ 7. , 30. , 11. , 23. , 18. , 10. , 26. , 40. ,  4. ,  9. , 22. ,
#         1. ,  3. , 20. , 25. , 13. , 19. , 15. , 35. , 31. , 24. , 17. ,
#         5. ,  2. , 12. , 28. ,  6. , 38. ,  0.5,  8. , 14. , 27. , 21. ,
#        51. , 34. , 16. , 29. , 32. , 43. , 33. , 45. , 36. , 37. , 44. ,
#        42. , 41. , 39. , 46. , 48. , 50. , 47. , 49. ])

# %% [markdown]
# > Great! We have successfully converted the 'YearsCodePro' column to a float64 dtype
#
# > Now lets take a look at the size of a company and how it relates to total compensation!

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
sns.histplot(data=df_cleaned, x='CompTotal')

# Let's sort the plot by the size of the company
order = ['I don’t know', '2 to 9 employees', '10 to 19 employees', '20 to 99 employees', '100 to 499 employees',
         '500 to 999 employees', '1,000 to 4,999 employees', '5,000 to 9,999 employees', '10,000 or more employees']

plt.subplot(1, 2, 2)
sns.countplot(data=df_cleaned, x='OrgSize', order=order)
plt.xticks(rotation=90);

# %% [markdown]
# > **The Annual Salary Histogram is skewed right, a majority of developers get paid 100k to 200k**
#
# > **It also looks like most developers work in a large organization with 10k or more employees**

# %%
# Let's see if the size of the company affects annual compensation.
# Let's group our data by orgsize and calculate the mean of compensation for each group.
org_salary = df_cleaned.groupby('OrgSize')['CompTotal'].mean()
org_salary
# Out:
# OrgSize
# 1,000 to 4,999 employees                              164574.938111
# 10 to 19 employees                                    139084.959494
# 10,000 or more employees                              181597.278653
# 100 to 499 employees                                  148269.835698
# 2 to 9 employees                                      125891.218818
# 20 to 99 employees                                    144748.279197
# 5,000 to 9,999 employees                              156481.319095
# 500 to 999 employees                                  153307.172691
# I don’t know                                          113278.750000
# Just me - I am a freelancer, sole proprietor, etc.    133883.397590
# Name: CompTotal, dtype: float64

# %%
# Let's now convert our groupby series into a pandas function.
org_salary = org_salary.reset_index(drop=False)
org_salary
# Out:
#                                              OrgSize      CompTotal
# 0                           1,000 to 4,999 employees  164574.938111
# 1                                 10 to 19 employees  139084.959494
# 2                           10,000 or more employees  181597.278653
# 3                               100 to 499 employees  148269.835698
# 4                                   2 to 9 employees  125891.218818
# 5                                 20 to 99 employees  144748.279197
# 6                           5,000 to 9,999 employees  156481.319095
# 7                               500 to 999 employees  153307.172691
# 8                                       I don’t know  113278.750000
# 9  Just me - I am a freelancer, sole proprietor, ...  133883.397590

# %%
# Let rename our CompTotal column to better represent its values and let's sort the renamed column in descending order
org_salary.rename(columns={'CompTotal':'MeanCompTotal'},inplace=True)
org_salary.sort_values(by='MeanCompTotal', ascending=False, inplace=True)

# Let's also reset the index (just good practice)
org_salary.reset_index(inplace=True, drop=True)

# Let's also rename 'Just me- I am a freelancer, sole proprestor, etc' to something shorter like 'Self-Employed'
org_salary.loc[org_salary['OrgSize'] == 'Just me - I am a freelancer, sole proprietor, etc.', 'OrgSize'] = 'Self-Employed'

org_salary
# Out:
#                     OrgSize  MeanCompTotal
# 0  10,000 or more employees  181597.278653
# 1  1,000 to 4,999 employees  164574.938111
# 2  5,000 to 9,999 employees  156481.319095
# 3      500 to 999 employees  153307.172691
# 4      100 to 499 employees  148269.835698
# 5        20 to 99 employees  144748.279197
# 6        10 to 19 employees  139084.959494
# 7             Self-Employed  133883.397590
# 8          2 to 9 employees  125891.218818
# 9              I don’t know  113278.750000

# %% [markdown]
# > **Let's visualize this on a barplot, so the information is easier to digest.**

# %%
sns.barplot(data=org_salary, x='OrgSize', y='MeanCompTotal')
plt.xticks(rotation=90);

# %% [markdown]
# ### Modeling
#
# > Select algorithms based on data characteristics
#
# > Train models and adjust hyperparameters to improve performance

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6881 entries, 389 to 65270
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           6881 non-null   object
#  1   EdLevel       6881 non-null   object
#  2   OrgSize       6881 non-null   object
#  3   Country       6881 non-null   object
#  4   CompTotal     6881 non-null   float64
#  5   YearsCodePro  6881 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 376.3+ KB

# %%
# We can  get rid of Country b/c we are only working with the United States of America
df_cleaned.drop('Country',axis=1, inplace=True)
# Out:
# /tmp/ipython-input-1718299088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop('Country',axis=1, inplace=True)

# %%
# Let's prep our data for our model
# We need to convert our categorical variables into a suitable format for our models

df_dummies = pd.get_dummies(df_cleaned, columns=['Age', 'EdLevel', 'OrgSize'])
df_dummies.head()
# Out:
#      CompTotal  YearsCodePro  Age_18-24 years old  Age_25-34 years old  \
# 389   110000.0           7.0                False                 True
# 398   195000.0          30.0                False                False
# 428   230000.0          11.0                False                 True
# 431    85000.0          23.0                False                False
# 432   160000.0          18.0                False                False
#
#      Age_35-44 years old  Age_45-54 years old  Age_55-64 years old  \
# 389                False                False                False
# 398                False                 True                False
# 428                False                False                False
# 431                 True                False                False
# 432                 True                False                False
#
#      Age_65 years or older  Age_Prefer not to say  Age_Under 18 years old  \
# 389                  False                  False                   False
# 398                  False                  False                   False
# 428                  False                  False                   False
# 431                  False                  False                   False
# 432                  False                  False                   False
#
#      EdLevel_Associate degree (A.A., A.S., etc.)  \
# 389                                        False
# 398                                        False
# 428                                        False
# 431                                        False
# 432                                        False
#
#      EdLevel_Bachelor’s degree (B.A., B.S., B.Eng., etc.)  \
# 389                                              False
# 398                                              False
# 428                                               True
# 431                                               True
# 432                                              False
#
#      EdLevel_Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  \
# 389                                              False
# 398                                              False
# 428                                              False
# 431                                              False
# 432                                              False
#
#      EdLevel_Primary/elementary school  \
# 389                              False
# 398                              False
# 428                              False
# 431                              False
# 432                              False
#
#      EdLevel_Professional degree (JD, MD, Ph.D, Ed.D, etc.)  \
# 389                                              False
# 398                                              False
# 428                                              False
# 431                                              False
# 432                                              False
#
#      EdLevel_Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)  \
# 389                                              False
# 398                                              False
# 428                                              False
# 431                                              False
# 432                                               True
#
#      EdLevel_Some college/university study without earning a degree  \
# 389                                               True
# 398                                               True
# 428                                              False
# 431                                              False
# 432                                              False
#
#      EdLevel_Something else  OrgSize_1,000 to 4,999 employees  \
# 389                   False                             False
# 398                   False                              True
# 428                   False                             False
# 431                   False                             False
# 432                   False                             False
#
#      OrgSize_10 to 19 employees  OrgSize_10,000 or more employees  \
# 389                        True                             False
# 398                       False                             False
# 428                       False                             False
# 431                       False                             False
# 432                        True                             False
#
#      OrgSize_100 to 499 employees  OrgSize_2 to 9 employees  \
# 389                         False                     False
# 398                         False                     False
# 428                          True                     False
# 431                         False                     False
# 432                         False                     False
#
#      OrgSize_20 to 99 employees  OrgSize_5,000 to 9,999 employees  \
# 389                       False                             False
# 398                       False                             False
# 428                       False                             False
# 431                        True                             False
# 432                       False                             False
#
#      OrgSize_500 to 999 employees  OrgSize_I don’t know  \
# 389                         False                 False
# 398                         False                 False
# 428                         False                 False
# 431                         False                 False
# 432                         False                 False
#
#      OrgSize_Just me - I am a freelancer, sole proprietor, etc.
# 389                                              False
# 398                                              False
# 428                                              False
# 431                                              False
# 432                                              False

# %%
y = df_dummies['CompTotal']
X = df_dummies.drop('CompTotal', axis=1)

# %%
# Creating a train_test_split on our X and y to evaluate our model later on
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=7)

# %%
# Importing model, I will be using scikit learn's Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# %%
# Instantiating Model & Training
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### Evaluating
#
# > Evaluating model accuracy using regression metrics such as r2 and RMSE
#
# > Validate model with unseen data to ensure generalization

# %%
# Grabing predictions for evaluations
y_test_pred = model.predict(X_test)  # Unseen Data
y_train_pred = model.predict(X_train) # Seen Data

# %%
# r2 evaluation
train_r2 = model.score(X_train, y_train)
test_r2 = model.score(X_test, y_test)

# root mean squared error evaluation
train_rmse = root_mean_squared_error(y_train, y_train_pred)
test_rmse = root_mean_squared_error(y_test, y_test_pred)

print(f'The R2 scores are train: {train_r2}, test: {test_r2}')
print(f'The RMSE values are train: {train_rmse}, test: {test_rmse}')
# Out:
# The R2 scores are train: 0.5217821940456029, test: 0.12964473500110185
# The RMSE values are train: 51060.95542020762, test: 74300.50428121853

# %% [markdown]
# ### Reflections:
# Both of our model's R2 score and RMSE value is not great. On top of that our r2 train score is way higher than our test score indicating that there is overfitting. I would love to learn how to make my predictive model more accurate, but as of this moment, that is beyond the scope of my knowledge.
